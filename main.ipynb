# %% [markdown]
# Useful links
# - https://liquipedia.net/commons/Liquipedia:API_Usage_Guidelines
# - https://liquipedia.net/leagueoflegends/index.php?title=Category:Players

# %% [markdown]
# BTW this whole thing made me think of the Futurama ep "The Problem with Popplers" where the only two company names that haven't been trademarked are "Popplers" and "Zitzels". See https://tvtropes.org/pmwiki/pmwiki.php/Recap/FuturamaS2E15TheProblemWithPopplers under Disney Owns This Trope.

# %% [markdown]
# ### Setup

# %%
import json
import os
import re
import time
from collections import Counter
from datetime import datetime

import main

# %%
exec_datetime = datetime.now().strftime("%Y%m%d%H%M%S")
print(exec_datetime)
# Out:
# 20241206223049

# %%
headers = {
    "User-Agent": "EsportUsernames/1.0 (https://github.com/hollowscene)"
}

# %% [markdown]
# ## League of Legends wiki

# %% [markdown]
# ### Import

# %%
wiki = "leagueoflegends"

# %%
players = main.get_player_pages(wiki=wiki, headers=headers)
player_names = [player["title"] for player in players]

# %%
# Cache raw names
data_subfolder = os.path.join("data", exec_datetime)
if not os.path.exists(data_subfolder):
    os.makedirs(data_subfolder)

with open(f"{data_subfolder}/{wiki}_player_names_raw.txt", "w") as f:
    f.write(json.dumps(player_names))

# %% [markdown]
# ### Clean

# %%
# Regex match against any name that ends with text in brackets
pattern = re.compile(r".+\ \(.+\)$")

matches = main.filter_items(pattern, player_names)
print(f"{len(matches):,} matches found")
print(matches)

# %%
cleaned_player_names = [main.clean_username(pattern, player_name) for player_name in player_names]
value_counts = Counter([player_name for player_name in cleaned_player_names])

print(f"Total player name count in {wiki} wiki: {len(player_names):,}")
print(f"Unique player name count in {wiki} wiki: {len(value_counts):,}")

# %%
value_counts.most_common()[:5]

# %% [markdown]
# There are indeed 4 'notable players/coaches/personalities' in League of Legends with the pseudonym Nova...
#
# 1. https://liquipedia.net/leagueoflegends/Nova
# 2. https://liquipedia.net/leagueoflegends/Nova_(Jonathan_Baadsgaard)
# 3. https://liquipedia.net/leagueoflegends/Nova_(Moroccan_player)
# 4. https://liquipedia.net/leagueoflegends/Nova_(Park_Chan-ho)

# %% [markdown]
# ### Store cleaned names

# %%
# Cache cleaned names
with open(f"{data_subfolder}/{wiki}_player_names_cleaned.txt", "w") as f:
    f.write(json.dumps(cleaned_player_names))

# %% [markdown]
# ## Multiple wikis

# %%
main_wiki_list = [
    "dota2",
    "counterstrike",
    "mobilelegends",
    "apexlegends",
    "overwatch",
    "pubgmobile",
    "smash",
    "honorofkings",
    "warcraft",
    "starcraft",
    "easportsfc",
    "hearthstone",
    "valorant",
    "rocketleague",
    "leagueoflegends",
    "rainbowsix",
    "starcraft2",
    "ageofempires",
    "fighters",
    "pubg",
    "brawlstars",
    "wildrift",
    "heroes",
    "artifact",
]

# %%
data_subfolder = os.path.join("data", exec_datetime)
if not os.path.exists(data_subfolder):
    os.makedirs(data_subfolder)

# %%
def ingest_and_clean(wiki, pattern=re.compile(r".+\ \(.+\)$")):

    players = main.get_player_pages(wiki=wiki, headers=headers)
    player_names = [player["title"] for player in players]

    # Cache raw names
    with open(os.path.join(data_subfolder, f"{wiki}_player_names_raw.txt"), "w") as f_raw:
        f_raw.write(json.dumps(player_names))

    cleaned_player_names = [main.clean_username(pattern, player_name) for player_name in player_names]
    value_counts = Counter([player_name for player_name in cleaned_player_names])

    print(f"Total player name count in {wiki} wiki: {len(player_names):,}")
    print(f"Unique player name count in {wiki} wiki: {len(value_counts):,}")

    # Cache cleaned names
    with open(os.path.join(data_subfolder, f"{wiki}_player_names_cleaned.txt"), "w") as f_cleaned:
        f_cleaned.write(json.dumps(cleaned_player_names))

# %%
for wiki in main_wiki_list:
    start_datetime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    print(f"{start_datetime} - {wiki} import and clean start")
    ingest_and_clean(wiki)
    end_datetime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    print(f"{end_datetime} - {wiki} import and clean finished")
    # time.sleep(2)
# Out:
# 2024-12-06 22:33:08 - dota2 import and clean start
# Total player name count in dota2 wiki: 1,744
# Unique player name count in dota2 wiki: 1,728
# 2024-12-06 22:33:13 - dota2 import and clean finished
# 2024-12-06 22:33:13 - counterstrike import and clean start
# Total player name count in counterstrike wiki: 3,536
# Unique player name count in counterstrike wiki: 3,491
# 2024-12-06 22:33:22 - counterstrike import and clean finished
# 2024-12-06 22:33:22 - mobilelegends import and clean start
# Total player name count in mobilelegends wiki: 1,379
# Unique player name count in mobilelegends wiki: 1,362
# 2024-12-06 22:33:25 - mobilelegends import and clean finished
# 2024-12-06 22:33:25 - apexlegends import and clean start
# Total player name count in apexlegends wiki: 1,989
# Unique player name count in apexlegends wiki: 1,984
# 2024-12-06 22:33:29 - apexlegends import and clean finished
# 2024-12-06 22:33:29 - overwatch import and clean start
# Total player name count in overwatch wiki: 3,954
# Unique player name count in overwatch wiki: 3,897
# 2024-12-06 22:33:38 - overwatch import and clean finished
# 2024-12-06 22:33:38 - pubgmobile import and clean start
# Total player name count in pubgmobile wiki: 2,540
# Unique player name count in pubgmobile wiki: 2,493
# 2024-12-06 22:33:45 - pubgmobile import and clean finished
# 2024-12-06 22:33:45 - smash import and clean start
# Total player name count in smash wiki: 3,758
# Unique player name count in smash wiki: 3,688
# 2024-12-06 22:33:54 - smash import and clean finished
# 2024-12-06 22:33:54 - honorofkings import and clean start
# Total player name count in honorofkings wiki: 1,308
# Unique player name count in honorofkings wiki: 1,278
# 2024-12-06 22:33:57 - honorofkings import and clean finished
# 2024-12-06 22:33:57 - warcraft import and clean start
# Total player name count in warcraft wiki: 1,419
# Unique player name count in warcraft wiki: 1,408
# 2024-12-06 22:34:00 - warcraft import and clean finished
# 2024-12-06 22:34:00 - starcraft import and clean start
# Total player name count in starcraft wiki: 746
# Unique player name count in starcraft wiki: 743
# 2024-12-06 22:34:03 - starcraft import and clean finished
# 2024-12-06 22:34:03 - easportsfc import and clean start
# Total player name count in easportsfc wiki: 952
# Unique player name count in easportsfc wiki: 951
# 2024-12-06 22:34:05 - easportsfc import and clean finished
# 2024-12-06 22:34:05 - hearthstone import and clean start
# Total player name count in hearthstone wiki: 1,171
# Unique player name count in hearthstone wiki: 1,166
# 2024-12-06 22:34:08 - hearthstone import and clean finished
# 2024-12-06 22:34:08 - valorant import and clean start
# Total player name count in valorant wiki: 3,324
# Unique player name count in valorant wiki: 3,282
# 2024-12-06 22:34:16 - valorant import and clean finished
# 2024-12-06 22:34:16 - rocketleague import and clean start
# Total player name count in rocketleague wiki: 2,226
# Unique player name count in rocketleague wiki: 2,193
# 2024-12-06 22:34:22 - rocketleague import and clean finished
# 2024-12-06 22:34:22 - leagueoflegends import and clean start
# Total player name count in leagueoflegends wiki: 4,674
# Unique player name count in leagueoflegends wiki: 4,575
# 2024-12-06 22:34:33 - leagueoflegends import and clean finished
# 2024-12-06 22:34:33 - rainbowsix import and clean start
# Total player name count in rainbowsix wiki: 2,914
# Unique player name count in rainbowsix wiki: 2,899
# 2024-12-06 22:34:39 - rainbowsix import and clean finished
# 2024-12-06 22:34:39 - starcraft2 import and clean start
# Total player name count in starcraft2 wiki: 1,829
# Unique player name count in starcraft2 wiki: 1,792
# 2024-12-06 22:34:44 - starcraft2 import and clean finished
# 2024-12-06 22:34:44 - ageofempires import and clean start
# Total player name count in ageofempires wiki: 1,079
# Unique player name count in ageofempires wiki: 1,075
# 2024-12-06 22:34:47 - ageofempires import and clean finished
# 2024-12-06 22:34:47 - fighters import and clean start
# Total player name count in fighters wiki: 2,058
# Unique player name count in fighters wiki: 2,040
# 2024-12-06 22:34:53 - fighters import and clean finished
# 2024-12-06 22:34:53 - pubg import and clean start
# Total player name count in pubg wiki: 1,669
# Unique player name count in pubg wiki: 1,666
# 2024-12-06 22:34:57 - pubg import and clean finished
# 2024-12-06 22:34:57 - brawlstars import and clean start
# Total player name count in brawlstars wiki: 431
# Unique player name count in brawlstars wiki: 429
# 2024-12-06 22:34:58 - brawlstars import and clean finished
# 2024-12-06 22:34:58 - wildrift import and clean start
# Total player name count in wildrift wiki: 749
# Unique player name count in wildrift wiki: 744
# 2024-12-06 22:35:01 - wildrift import and clean finished
# 2024-12-06 22:35:01 - heroes import and clean start
# Total player name count in heroes wiki: 916
# Unique player name count in heroes wiki: 914
# 2024-12-06 22:35:03 - heroes import and clean finished
# 2024-12-06 22:35:03 - artifact import and clean start
# Total player name count in artifact wiki: 149
# Unique player name count in artifact wiki: 149
# 2024-12-06 22:35:04 - artifact import and clean finished

# %% [markdown]
# ## Analysis

# %%
json.loads(f"leagueoflegends")
